# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vehicles_dataset_upd.csv')
df.head()
# Out:
#            id                                                url  \
# 0  7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...
# 1  7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...
# 2  7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...
# 3  7308210929  https://fayetteville.craigslist.org/ctd/d/rale...
# 4  7316474668  https://newyork.craigslist.org/lgi/cto/d/baldw...
#
#           region                           region_url  price  year  \
# 0    chattanooga   https://chattanooga.craigslist.org  54990  2020
# 1   north jersey     https://newjersey.craigslist.org  16942  2016
# 2   reno / tahoe          https://reno.craigslist.org  35590  2017
# 3   fayetteville  https://fayetteville.craigslist.org  14500  2013
# 4  new york city       https://newyork.craigslist.org  21800  2021
#
#   manufacturer                   model    fuel  odometer title_status  \
# 0          ram  2500 crew cab big horn  diesel     27442        clean
# ...

# %% [markdown]
# # 19.1 Введение в визуализацию данных. Библиотека matplotlib

# %%
plt.hist(df.odometer);

# %%
plt.figure(figsize=(8,5))
plt.hist(df.odometer, bins=15, color='green')
plt.xlabel('Количество пройденных миль')
plt.ylabel('Частота')
plt.title('Распредение количества пройденных миль');

# %% [markdown]
# # 19.2 Выявление аномалий при помощи визуализации

# %%
df_with_out = pd.read_csv('df_types_upd.csv')
df_with_out.head()
# Out:
#            id                                                url  \
# 0  7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...
# 1  7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...
# 2  7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...
# 3  7308210929  https://fayetteville.craigslist.org/ctd/d/rale...
# 4  7316474668  https://newyork.craigslist.org/lgi/cto/d/baldw...
#
#           region                           region_url  price    year  \
# 0    chattanooga   https://chattanooga.craigslist.org  54990  2020.0
# 1   north jersey     https://newjersey.craigslist.org  16942  2016.0
# 2   reno / tahoe          https://reno.craigslist.org  35590  2017.0
# 3   fayetteville  https://fayetteville.craigslist.org  14500  2013.0
# 4  new york city       https://newyork.craigslist.org  21800  2021.0
#
#   manufacturer                   model    fuel  odometer title_status  \
# 0          ram  2500 crew cab big horn  diesel     27442        clean
# ...

# %%
plt.figure(figsize=(8,5))
plt.hist(df.odometer)
plt.xlabel('Количество пройденных миль')
plt.ylabel('Частота')
plt.title('Распредение количества пройденных миль');

# %%
plt.figure(figsize=(8,5))
plt.hist(df_with_out.odometer)
plt.xlabel('Количество пройденных миль')
plt.ylabel('Частота')
plt.title('Распредение количества пройденных миль');

# %%
plt.figure(figsize=(12, 8))
plt.hist(df_with_out.odometer, bins=100)
plt.xlabel('Количество пройденных миль')
plt.ylabel('Частота')
plt.title('Распредение количества пройденных миль');

# %%
from matplotlib.ticker import FormatStrFormatter

fig, ax = plt.subplots(figsize=(12, 12))

ax.hist(df_with_out.odometer, bins=(100), color='r')
ax.set_xlabel('Количество пройденных миль')
ax.set_ylabel('Частота')
ax.set_title('Распредение количества пройденных миль (с аномалиями)');

ax.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# %%
plt.figure(figsize=(8, 5))
plt.boxplot(df.odometer)
plt.ylabel('Количество пройденных миль')
plt.title('Ящик с усами для количества пройденных миль (без аномалий)');

# %%
df.odometer.describe()
# Out:
# count      9868.000000
# mean      93652.071342
# std       63274.797554
# min           0.000000
# 25%       39252.500000
# 50%       89116.000000
# 75%      137198.250000
# max      283995.000000
# Name: odometer, dtype: float64

# %%
from matplotlib.ticker import FormatStrFormatter

fig, ax = plt.subplots(figsize=(8, 8))

ax.boxplot(df_with_out.odometer)
ax.set_ylabel('Kоличество пройденных миль')
ax.set_title('Распредение количества пройденных миль (с аномалиями)');

ax.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))

# %%
df_with_out.odometer.describe().apply(lambda x: f"{x:0.3f}")
# Out:
# count       9902.000
# mean       95753.989
# std        86773.160
# min            0.000
# 25%        39003.250
# 50%        89000.000
# 75%       137000.000
# max      3245000.000
# Name: odometer, dtype: object

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(8, 8), sharey=True)

ax1.boxplot(df.odometer)
ax1.set_title('Без аномалий');


ax2.boxplot(df_with_out.odometer)
ax2.set_title('C аномалиями');


ax1.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
fig.suptitle('Kоличество пройденных миль');

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(20, 8), sharex=True)

ax1.hist(df_with_out.odometer, bins=100, color='orange')
ax1.set_title('Гистограмма');
ax1.axvline(df_with_out.odometer.median(), color='red', linestyle='dashed', linewidth=1)

ax2.boxplot(df_with_out.odometer, vert=False)
ax2.set_title('Ящик с усами');


ax1.xaxis.set_major_formatter(FormatStrFormatter('%.0f'))
fig.suptitle('Kоличество пройденных миль');

# %% [markdown]
# # 19.3 Визуализация категориальных переменных

# %%
stats = df.groupby(['year', 'price_category']).agg({'fuel': 'first',
                                                    'odometer': 'mean'})
stats = stats.rename(columns={'fuel': 'fuel_first', 'odometer': 'odometer_mean'})
stats
# Out:
#                     fuel_first  odometer_mean
# year price_category
# 1995 high                  gas   57305.753086
#      low                   gas  105530.054187
#      medium                gas   69436.685315
# 1996 high                other  153710.000000
#      low                   gas  136428.187500
# ...                        ...            ...
# 2021 high                  gas    2459.433333
#      low                 other   29316.900000
#      medium                gas   49381.875000
# 2022 high                  gas  142002.500000
#      low                   gas  180000.000000
#
# [82 rows x 2 columns]

# %%
stats = df.groupby(['fuel'], as_index=False)[['id']].count()
stats = stats.rename(columns={'id': 'count'})

stats
# Out:
#        fuel  count
# 0    diesel    643
# 1  electric     44
# 2       gas   8298
# 3    hybrid    104
# 4     other    779

# %%
plt.bar(stats.fuel, stats['count'], color=['orange', 'red', 'green'])
plt.xlabel('Тип топлива')
plt.ylabel('Количество')
plt.title('Распределние типа топлива')
# Out:
# Text(0.5, 1.0, 'Распределние типа топлива')

# %%
plt.figure(figsize=(12, 8))
plt.pie(stats['count'], labels=stats['fuel'], autopct='%1.0f%%')
plt.title('Распределние типа топлива')
plt.legend()
plt.show()

# %% [markdown]
# # 19.4 Корреляции

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('vehicles_dataset_upd.csv')
df.head()
# Out:
#            id                                                url  \
# 0  7308295377  https://chattanooga.craigslist.org/ctd/d/chatt...
# 1  7316380095  https://newjersey.craigslist.org/ctd/d/carlsta...
# 2  7313733749  https://reno.craigslist.org/ctd/d/atlanta-2017...
# 3  7308210929  https://fayetteville.craigslist.org/ctd/d/rale...
# 4  7316474668  https://newyork.craigslist.org/lgi/cto/d/baldw...
#
#           region                           region_url  price  year  \
# 0    chattanooga   https://chattanooga.craigslist.org  54990  2020
# 1   north jersey     https://newjersey.craigslist.org  16942  2016
# 2   reno / tahoe          https://reno.craigslist.org  35590  2017
# 3   fayetteville  https://fayetteville.craigslist.org  14500  2013
# 4  new york city       https://newyork.craigslist.org  21800  2021
#
#   manufacturer                   model    fuel  odometer title_status  \
# 0          ram  2500 crew cab big horn  diesel     27442        clean
# ...

# %%
colors = {'low':'green','medium': 'orange', 'high': 'red'}
fig, ax = plt.subplots(figsize=(12, 8))

for price_category in colors:
    color = colors[price_category]
    data = df[df['price_category'] == price_category]
    ax.hist(data['odometer'], bins=20, color=color, alpha=0.7)
    
plt.xlabel('Пробег автомобиля')
plt.ylabel('Количество')
plt.title('Количество пройденных миль в зависимости от ценовой категории автомобиля');
plt.legend(colors, title='Ценовая категория');

# %%
plt.figure(figsize=(12,8))
plt.scatter(df['odometer'], df['year'])
plt.title('Зависимость пробега от года выпуска автомобиля')
plt.xlabel('Пробег')
plt.ylabel('Год выпуска')

plt.show()

# %%
colors = {'low': 'green', 'medium': 'orange', 'high': 'red'}
fig, ax = plt.subplots(figsize=(12, 8))

for price_category in colors:
    color = colors[price_category]
    data = df[df['price_category'] == price_category]
    ax.scatter(data['odometer'], data['year'], c=color, label=price_category)
    
ax.legend(loc='upper right', title='Ценовая категория')
plt.title('Зависимость пробега от года выпуска автомобиля')
plt.xlabel('Пробег')
plt.ylabel('Год выпуска')
plt.show()

# %%
df['year'].corr(df['odometer'])
# Out:
# -0.5087961565425962

# %%
df.corr()
# Out:
# C:\Users\e.kuzmina\AppData\Local\Temp\ipykernel_12716\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                 id     price      year  odometer       lat      long
# id        1.000000 -0.032689 -0.100205  0.048796 -0.077752 -0.106567
# price    -0.032689  1.000000  0.072763 -0.057455  0.002235 -0.001371
# year     -0.100205  0.072763  1.000000 -0.508796 -0.031854  0.007378
# odometer  0.048796 -0.057455 -0.508796  1.000000  0.024401  0.007551
# lat      -0.077752  0.002235 -0.031854  0.024401  1.000000 -0.164737
# long     -0.106567 -0.001371  0.007378  0.007551 -0.164737  1.000000

# %%
plt.figure(figsize=(12,8))

columns = df.corr().columns.tolist()
plt.imshow(df.corr())

plt.title('Корреляция численных признаков')
plt.xticks(range(0, len(columns)), columns)
plt.yticks(range(0, len(columns)), columns)
plt.colorbar()
plt.show()
# Out:
# C:\Users\e.kuzmina\AppData\Local\Temp\ipykernel_12716\2618202749.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   columns = df.corr().columns.tolist()
# C:\Users\e.kuzmina\AppData\Local\Temp\ipykernel_12716\2618202749.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   plt.imshow(df.corr())
