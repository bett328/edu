# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = [['Tomsk', 70],
        ['Omsk', 50]]

# %%
df = pd.DataFrame(data, columns=['city', 'code'])
df
# Out:
#     city  code
# 0  Tomsk    70
# 1   Omsk    50

# %%
data = [{'city': 'Tomsk', 'code': 70},
        {'city': 'Omsk', 'code': 50}]

# %%
df = pd.DataFrame(data)
df
# Out:
#     city  code
# 0  Tomsk    70
# 1   Omsk    50

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['city']
# Out:
# 0    Tomsk
# 1     Omsk
# Name: city, dtype: object

# %%
type(df['city'])
# Out:
# pandas.core.series.Series

# %%
pd.Series(['Tomsk', 'Omsk'], name='city')
# Out:
# 0    Tomsk
# 1     Omsk
# Name: city, dtype: object

# %%
pd.DataFrame(pd.Series(['Tomsk', 'Omsk'], name='city'))
# Out:
#     city
# 0  Tomsk
# 1   Omsk

# %%
df = pd.DataFrame({'city': pd.Series(['Tomsk', 'Omsk']),
                  'code': pd.Series([70, 50])})

# %%
df
# Out:
#     city  code
# 0  Tomsk    70
# 1   Omsk    50

# %%
help(pd.read_excel)
# Out:
# Help on function read_excel in module pandas.io.excel._base:
#
# ...

# %%
df = pd.read_excel('./12.2 Данные для урока и практики/12.2 Данные для урока и практики/partner_data.xlsx', sheet_name='partner_data1', header=0)
df
# Out:
#        id   age           job  marital  education  balance housing loan  \
# 0       1  26.0    unemployed  married   tertiary      454     yes  yes
# 1       2  25.0    technician  married  secondary      517      no   no
# 2       3  36.0    technician   single  secondary     1044     yes   no
# 3       4  45.0   blue-collar  married  secondary      146     yes  yes
# 4       5  27.0    management  married   tertiary      145      no   no
# ..    ...   ...           ...      ...        ...      ...     ...  ...
# 995   996  41.0  entrepreneur  married  secondary    -1882     yes   no
# 996   997  58.0    management  married   tertiary     1271     yes   no
# 997   998  31.0      services   single  secondary      297      no   no
# 998   999  31.0  entrepreneur      NaN   tertiary      312      no   no
# 999  1000  23.0   blue-collar   single  secondary      780     yes   no
#
#     default
# 0        no
# 1        no
# 2        no
# 3        no
# 4        no
# ..      ...
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.columns
# Out:
# Index(['id', 'age', 'job', 'marital', 'education', 'balance', 'housing',
#        'loan', 'default'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df = pd.read_excel('./12.2 Данные для урока и практики/12.2 Данные для урока и практики/partner_data.xlsx', sheet_name='partner_data1', header=0, index_col='id')
df
# Out:
#        age           job  marital  education  balance housing loan default
# id
# 1     26.0    unemployed  married   tertiary      454     yes  yes      no
# 2     25.0    technician  married  secondary      517      no   no      no
# 3     36.0    technician   single  secondary     1044     yes   no      no
# 4     45.0   blue-collar  married  secondary      146     yes  yes      no
# 5     27.0    management  married   tertiary      145      no   no      no
# ...    ...           ...      ...        ...      ...     ...  ...     ...
# 996   41.0  entrepreneur  married  secondary    -1882     yes   no      no
# 997   58.0    management  married   tertiary     1271     yes   no      no
# 998   31.0      services   single  secondary      297      no   no      no
# 999   31.0  entrepreneur      NaN   tertiary      312      no   no      no
# 1000  23.0   blue-collar   single  secondary      780     yes   no      no
#
# [1000 rows x 8 columns]

# %%
df.head()
# Out:
#      age          job  marital  education  balance housing loan default
# id
# 1   26.0   unemployed  married   tertiary      454     yes  yes      no
# 2   25.0   technician  married  secondary      517      no   no      no
# 3   36.0   technician   single  secondary     1044     yes   no      no
# 4   45.0  blue-collar  married  secondary      146     yes  yes      no
# 5   27.0   management  married   tertiary      145      no   no      no

# %%
df.tail()
# Out:
#        age           job  marital  education  balance housing loan default
# id
# 996   41.0  entrepreneur  married  secondary    -1882     yes   no      no
# 997   58.0    management  married   tertiary     1271     yes   no      no
# 998   31.0      services   single  secondary      297      no   no      no
# 999   31.0  entrepreneur      NaN   tertiary      312      no   no      no
# 1000  23.0   blue-collar   single  secondary      780     yes   no      no

# %%
df.head(10)
# Out:
#      age          job   marital  education  balance housing loan default
# id
# 1   26.0   unemployed   married   tertiary      454     yes  yes      no
# 2   25.0   technician   married  secondary      517      no   no      no
# 3   36.0   technician    single  secondary     1044     yes   no      no
# 4   45.0  blue-collar   married  secondary      146     yes  yes      no
# 5   27.0   management   married   tertiary      145      no   no      no
# 6   45.0   unemployed  divorced    primary       11      no   no     yes
# 7   35.0   management   married   tertiary      298     yes   no      no
# 8   27.0   technician    single  secondary      905     yes  yes      no
# 9    NaN   management   married   tertiary     -485     yes   no     yes
# 10  32.0   unemployed   married  secondary       10     yes   no      no

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
pd.read_csv('./12.2 Данные для урока и практики/12.2 Данные для урока и практики/partner_data.csv')
# Out:
#        id   age           job  marital  education  balance housing loan  \
# 0       1  26.0    unemployed  married   tertiary      454     yes  yes
# 1       2  25.0    technician  married  secondary      517      no   no
# 2       3  36.0    technician   single  secondary     1044     yes   no
# 3       4  45.0   blue-collar  married  secondary      146     yes  yes
# 4       5  27.0    management  married   tertiary      145      no   no
# ..    ...   ...           ...      ...        ...      ...     ...  ...
# 995   996  41.0  entrepreneur  married  secondary    -1882     yes   no
# 996   997  58.0    management  married   tertiary     1271     yes   no
# 997   998  31.0      services   single  secondary      297      no   no
# 998   999  31.0  entrepreneur      NaN   tertiary      312      no   no
# 999  1000  23.0   blue-collar   single  secondary      780     yes   no
#
#     default
# 0        no
# 1        no
# 2        no
# 3        no
# 4        no
# ..      ...
# ...

# %%
pd.read_csv('./12.2 Данные для урока и практики/12.2 Данные для урока и практики/partner_data_semicolon.csv')
# Out:
#     id;age;job;marital;education;balance;housing;loan;default
# 0    1;26.0;unemployed;married;tertiary;454;yes;yes;no
# 1     2;25.0;technician;married;secondary;517;no;no;no
# 2    3;36.0;technician;single;secondary;1044;yes;no;no
# 3    4;45.0;blue-collar;married;secondary;146;yes;y...
# 4      5;27.0;management;married;tertiary;145;no;no;no
# ..                                                 ...
# 995  996;41.0;entrepreneur;married;secondary;-1882;...
# 996  997;58.0;management;married;tertiary;1271;yes;...
# 997    998;31.0;services;single;secondary;297;no;no;no
# 998       999;31.0;entrepreneur;;tertiary;312;no;no;no
# 999  1000;23.0;blue-collar;single;secondary;780;yes...
#
# [1000 rows x 1 columns]

# %%
pd.read_csv('./12.2 Данные для урока и практики/12.2 Данные для урока и практики/partner_data_semicolon.csv', sep=';')
# Out:
#        id   age           job  marital  education  balance housing loan  \
# 0       1  26.0    unemployed  married   tertiary      454     yes  yes
# 1       2  25.0    technician  married  secondary      517      no   no
# 2       3  36.0    technician   single  secondary     1044     yes   no
# 3       4  45.0   blue-collar  married  secondary      146     yes  yes
# 4       5  27.0    management  married   tertiary      145      no   no
# ..    ...   ...           ...      ...        ...      ...     ...  ...
# 995   996  41.0  entrepreneur  married  secondary    -1882     yes   no
# 996   997  58.0    management  married   tertiary     1271     yes   no
# 997   998  31.0      services   single  secondary      297      no   no
# 998   999  31.0  entrepreneur      NaN   tertiary      312      no   no
# 999  1000  23.0   blue-collar   single  secondary      780     yes   no
#
#     default
# 0        no
# 1        no
# 2        no
# 3        no
# 4        no
# ..      ...
# ...

# %%
pd.read_csv('./12.2 Данные для урока и практики/12.2 Данные для урока и практики/partner_data_semicolon.csv', delimiter=';')
# Out:
#        id   age           job  marital  education  balance housing loan  \
# 0       1  26.0    unemployed  married   tertiary      454     yes  yes
# 1       2  25.0    technician  married  secondary      517      no   no
# 2       3  36.0    technician   single  secondary     1044     yes   no
# 3       4  45.0   blue-collar  married  secondary      146     yes  yes
# 4       5  27.0    management  married   tertiary      145      no   no
# ..    ...   ...           ...      ...        ...      ...     ...  ...
# 995   996  41.0  entrepreneur  married  secondary    -1882     yes   no
# 996   997  58.0    management  married   tertiary     1271     yes   no
# 997   998  31.0      services   single  secondary      297      no   no
# 998   999  31.0  entrepreneur      NaN   tertiary      312      no   no
# 999  1000  23.0   blue-collar   single  secondary      780     yes   no
#
#     default
# 0        no
# 1        no
# 2        no
# 3        no
# 4        no
# ..      ...
# ...

# %%
pd.read_csv('./12.2 Данные для урока и практики/12.2 Данные для урока и практики/partner_data_semicolon.csv', 
            delimiter=';', index_col='id')
# Out:
#        age           job  marital  education  balance housing loan default
# id
# 1     26.0    unemployed  married   tertiary      454     yes  yes      no
# 2     25.0    technician  married  secondary      517      no   no      no
# 3     36.0    technician   single  secondary     1044     yes   no      no
# 4     45.0   blue-collar  married  secondary      146     yes  yes      no
# 5     27.0    management  married   tertiary      145      no   no      no
# ...    ...           ...      ...        ...      ...     ...  ...     ...
# 996   41.0  entrepreneur  married  secondary    -1882     yes   no      no
# 997   58.0    management  married   tertiary     1271     yes   no      no
# 998   31.0      services   single  secondary      297      no   no      no
# 999   31.0  entrepreneur      NaN   tertiary      312      no   no      no
# 1000  23.0   blue-collar   single  secondary      780     yes   no      no
#
# [1000 rows x 8 columns]

# %%
df.iloc[0, 0]
# Out:
# 26.0

# %%
df.iloc[0:3, 0]
# Out:
# id
# 1    26.0
# 2    25.0
# 3    36.0
# Name: age, dtype: float64

# %%
df.iloc[:, 0]
# Out:
# id
# 1       26.0
# 2       25.0
# 3       36.0
# 4       45.0
# 5       27.0
#         ...
# 996     41.0
# 997     58.0
# 998     31.0
# 999     31.0
# 1000    23.0
# Name: age, Length: 1000, dtype: float64

# %%
df.iloc[0, :]
# Out:
# age                26.0
# job          unemployed
# marital         married
# education      tertiary
# balance             454
# housing             yes
# loan                yes
# default              no
# Name: 1, dtype: object

# %%
df.iloc[4:6, 2:4]
# Out:
#      marital education
# id
# 5    married  tertiary
# 6   divorced   primary

# %%
df.loc[1, 'age']
# Out:
# 26.0

# %%
df.loc[1:3, 'age']
# Out:
# id
# 1    26.0
# 2    25.0
# 3    36.0
# Name: age, dtype: float64

# %%
df.loc[:, 'age']
# Out:
# id
# 1       26.0
# 2       25.0
# 3       36.0
# 4       45.0
# 5       27.0
#         ...
# 996     41.0
# 997     58.0
# 998     31.0
# 999     31.0
# 1000    23.0
# Name: age, Length: 1000, dtype: float64

# %%
df.loc[5:6, 'marital':'education']
# Out:
#      marital education
# id
# 5    married  tertiary
# 6   divorced   primary

# %%
df.loc[[5,10], ['marital', 'default']]
# Out:
#     marital default
# id
# 5   married      no
# 10  married      no

# %%
df['age']
# Out:
# id
# 1       26.0
# 2       25.0
# 3       36.0
# 4       45.0
# 5       27.0
#         ...
# 996     41.0
# 997     58.0
# 998     31.0
# 999     31.0
# 1000    23.0
# Name: age, Length: 1000, dtype: float64

# %%
df[['marital', 'age']]
# Out:
#       marital   age
# id
# 1     married  26.0
# 2     married  25.0
# 3      single  36.0
# 4     married  45.0
# 5     married  27.0
# ...       ...   ...
# 996   married  41.0
# 997   married  58.0
# 998    single  31.0
# 999       NaN  31.0
# 1000   single  23.0
#
# [1000 rows x 2 columns]
