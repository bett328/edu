# %%
import json
import pandas as pd

# %%
with open('partner_data_records.json', 'r') as j:
    contents = json.load(j)

contents
# Out:
# [{'id': 1,
#   'age': 26.0,
#   'job': 'unemployed',
#   'marital': 'married',
#   'education': 'tertiary',
#   'balance': 454,
#   'housing': 'yes',
#   'loan': 'yes',
#   'default': 'no'},
#  {'id': 2,
#   'age': 25.0,
#   'job': 'technician',
#   'marital': 'married',
#   'education': 'secondary',
#   'balance': 517,
#   'housing': 'no',
#   'loan': 'no',
#   'default': 'no'},
#  {'id': 3,
#   'age': 36.0,
#   'job': 'technician',
#   'marital': 'single',
#   'education': 'secondary',
#   'balance': 1044,
#   'housing': 'yes',
#   'loan': 'no',
#   'default': 'no'},
#  {'id': 4,
#   'age': 45.0,
#   'job': 'blue-collar',
#   'marital': 'married',
#   'education': 'secondary',
#   'balance': 146,
#   'housing': 'yes',
#   'loan': 'yes',
#   'default': 'no'},
#  {'id': 5,
#   'age': 27.0,
#   'job': 'management',
#   'marital': 'married',
#   'education': 'tertiary',
#   'balance': 145,
#   'housing': 'no',
#   'loan': 'no',
#   'default': 'no'},
#  {'id': 6,
#   'age': 45.0,
# ...

# %%
len(contents)
# Out:
# 1000

# %%
contents[1]
# Out:
# {'id': 2,
#  'age': 25.0,
#  'job': 'technician',
#  'marital': 'married',
#  'education': 'secondary',
#  'balance': 517,
#  'housing': 'no',
#  'loan': 'no',
#  'default': 'no'}

# %%
contents[1]['balance']
# Out:
# 517

# %%
help(pd.read_json)
# Out:
# Help on function read_json in module pandas.io.json._json:
#
# read_json(path_or_buf: 'FilePath | ReadBuffer[str] | ReadBuffer[bytes]', *, orient: 'str | None' = None, typ: "Literal['frame', 'series']" = 'frame', dtype: 'DtypeArg | None' = None, convert_axes=None, convert_dates: 'bool | list[str]' = True, keep_default_dates: 'bool' = True, numpy: 'bool' = False, precise_float: 'bool' = False, date_unit: 'str | None' = None, encoding: 'str | None' = None, encoding_errors: 'str | None' = 'strict', lines: 'bool' = False, chunksize: 'int | None' = None, compression: 'CompressionOptions' = 'infer', nrows: 'int | None' = None, storage_options: 'StorageOptions' = None) -> 'DataFrame | Series | JsonReader'
#     Convert a JSON string to pandas object.
#
#     Parameters
#     ----------
#     path_or_buf : a valid JSON str, path object or file-like object
#         Any valid string path is acceptable. The string could be a URL. Valid
# ...

# %%
pd.read_json('partner_data_records.json')
# Out:
#        id   age           job  marital  education  balance housing loan  \
# 0       1  26.0    unemployed  married   tertiary      454     yes  yes
# 1       2  25.0    technician  married  secondary      517      no   no
# 2       3  36.0    technician   single  secondary     1044     yes   no
# 3       4  45.0   blue-collar  married  secondary      146     yes  yes
# 4       5  27.0    management  married   tertiary      145      no   no
# ..    ...   ...           ...      ...        ...      ...     ...  ...
# 995   996  41.0  entrepreneur  married  secondary    -1882     yes   no
# 996   997  58.0    management  married   tertiary     1271     yes   no
# 997   998  31.0      services   single  secondary      297      no   no
# 998   999  31.0  entrepreneur     None   tertiary      312      no   no
# 999  1000  23.0   blue-collar   single  secondary      780     yes   no
#
#     default
# 0        no
# 1        no
# 2        no
# 3        no
# 4        no
# ..      ...
# ...

# %%
pd.read_json('partner_data_records.json', index_col='id')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.read_json('partner_data_records.json', index_col='id')
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df = pd.read_json('partner_data_records.json')
df
# Out:
#        id   age           job  marital  education  balance housing loan  \
# 0       1  26.0    unemployed  married   tertiary      454     yes  yes
# 1       2  25.0    technician  married  secondary      517      no   no
# 2       3  36.0    technician   single  secondary     1044     yes   no
# 3       4  45.0   blue-collar  married  secondary      146     yes  yes
# 4       5  27.0    management  married   tertiary      145      no   no
# ..    ...   ...           ...      ...        ...      ...     ...  ...
# 995   996  41.0  entrepreneur  married  secondary    -1882     yes   no
# 996   997  58.0    management  married   tertiary     1271     yes   no
# 997   998  31.0      services   single  secondary      297      no   no
# 998   999  31.0  entrepreneur     None   tertiary      312      no   no
# 999  1000  23.0   blue-collar   single  secondary      780     yes   no
#
#     default
# 0        no
# 1        no
# 2        no
# 3        no
# 4        no
# ..      ...
# ...

# %%
df.set_index('id')
# Out:
#        age           job  marital  education  balance housing loan default
# id
# 1     26.0    unemployed  married   tertiary      454     yes  yes      no
# 2     25.0    technician  married  secondary      517      no   no      no
# 3     36.0    technician   single  secondary     1044     yes   no      no
# 4     45.0   blue-collar  married  secondary      146     yes  yes      no
# 5     27.0    management  married   tertiary      145      no   no      no
# ...    ...           ...      ...        ...      ...     ...  ...     ...
# 996   41.0  entrepreneur  married  secondary    -1882     yes   no      no
# 997   58.0    management  married   tertiary     1271     yes   no      no
# 998   31.0      services   single  secondary      297      no   no      no
# 999   31.0  entrepreneur     None   tertiary      312      no   no      no
# 1000  23.0   blue-collar   single  secondary      780     yes   no      no
#
# [1000 rows x 8 columns]

# %%
df.head()
# Out:
#    id   age          job  marital  education  balance housing loan default
# 0   1  26.0   unemployed  married   tertiary      454     yes  yes      no
# 1   2  25.0   technician  married  secondary      517      no   no      no
# 2   3  36.0   technician   single  secondary     1044     yes   no      no
# 3   4  45.0  blue-collar  married  secondary      146     yes  yes      no
# 4   5  27.0   management  married   tertiary      145      no   no      no

# %%
df = pd.read_json('partner_data_records.json')
df.set_index('id', inplace=True)
df
# Out:
#        age           job  marital  education  balance housing loan default
# id
# 1     26.0    unemployed  married   tertiary      454     yes  yes      no
# 2     25.0    technician  married  secondary      517      no   no      no
# 3     36.0    technician   single  secondary     1044     yes   no      no
# 4     45.0   blue-collar  married  secondary      146     yes  yes      no
# 5     27.0    management  married   tertiary      145      no   no      no
# ...    ...           ...      ...        ...      ...     ...  ...     ...
# 996   41.0  entrepreneur  married  secondary    -1882     yes   no      no
# 997   58.0    management  married   tertiary     1271     yes   no      no
# 998   31.0      services   single  secondary      297      no   no      no
# 999   31.0  entrepreneur     None   tertiary      312      no   no      no
# 1000  23.0   blue-collar   single  secondary      780     yes   no      no
#
# [1000 rows x 8 columns]

# %%
df = pd.read_json('partner_data_records.json')
df = df.set_index('id')
df
# Out:
#        age           job  marital  education  balance housing loan default
# id
# 1     26.0    unemployed  married   tertiary      454     yes  yes      no
# 2     25.0    technician  married  secondary      517      no   no      no
# 3     36.0    technician   single  secondary     1044     yes   no      no
# 4     45.0   blue-collar  married  secondary      146     yes  yes      no
# 5     27.0    management  married   tertiary      145      no   no      no
# ...    ...           ...      ...        ...      ...     ...  ...     ...
# 996   41.0  entrepreneur  married  secondary    -1882     yes   no      no
# 997   58.0    management  married   tertiary     1271     yes   no      no
# 998   31.0      services   single  secondary      297      no   no      no
# 999   31.0  entrepreneur     None   tertiary      312      no   no      no
# 1000  23.0   blue-collar   single  secondary      780     yes   no      no
#
# [1000 rows x 8 columns]

# %%
pd.read_json('partner_data_records_cp1251.json', encoding='cp1251')
# Out:
#        id   age           job  marital  education  balance housing loan  \
# 0       1  26.0   безработный  married     высшее      454      да   да
# 1       2  25.0    technician  married  secondary      517      no   no
# 2       3  36.0    technician   single  secondary     1044     yes   no
# 3       4  45.0   blue-collar  married  secondary      146     yes  yes
# 4       5  27.0    management  married   tertiary      145      no   no
# ..    ...   ...           ...      ...        ...      ...     ...  ...
# 995   996  41.0  entrepreneur  married  secondary    -1882     yes   no
# 996   997  58.0    management  married   tertiary     1271     yes   no
# 997   998  31.0      services   single  secondary      297      no   no
# 998   999  31.0  entrepreneur     None   tertiary      312      no   no
# 999  1000  23.0   blue-collar   single  secondary      780     yes   no
#
#     default
# 0       нет
# 1        no
# 2        no
# 3        no
# 4        no
# ..      ...
# ...

# %%
# !python --version
# Out:
# Python 3.10.9

# %%
df = pd.read_json('partner_data_records.json')
df = df.set_index('id')
df.head()
# Out:
#      age          job  marital  education  balance housing loan default
# id
# 1   26.0   unemployed  married   tertiary      454     yes  yes      no
# 2   25.0   technician  married  secondary      517      no   no      no
# 3   36.0   technician   single  secondary     1044     yes   no      no
# 4   45.0  blue-collar  married  secondary      146     yes  yes      no
# 5   27.0   management  married   tertiary      145      no   no      no

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.describe()
# Out:
#               age       balance
# count  901.000000   1000.000000
# mean    40.819090   1334.894000
# std     11.220097   2746.106944
# min     18.000000  -3372.000000
# 25%     32.000000     67.750000
# 50%     39.000000    484.000000
# 75%     48.000000   1495.250000
# max     88.000000  36221.000000

# %%
df.describe().loc['min', 'balance']
# Out:
# -3372.0

# %%
df['balance'].min()
# Out:
# -3372

# %%
df.balance.min()
# Out:
# -3372

# %%
df.min()
# Out:
# C:\Users\e.kuzmina\AppData\Local\Temp\ipykernel_18408\3962516015.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# age             18.0
# job           admin.
# education    primary
# balance        -3372
# housing           no
# loan              no
# default           no
# dtype: object

# %%
df.max()
# Out:
# C:\Users\e.kuzmina\AppData\Local\Temp\ipykernel_18408\1151452817.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# age             88.0
# job          unknown
# education    unknown
# balance        36221
# housing          yes
# loan             yes
# default          yes
# dtype: object

# %%
df.max(numeric_only=True)
# Out:
# age           88.0
# balance    36221.0
# dtype: float64

# %%
df.max(axis='columns')
# Out:
# C:\Users\e.kuzmina\AppData\Local\Temp\ipykernel_18408\3427301757.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max(axis='columns')
# id
# 1        454.0
# 2        517.0
# 3       1044.0
# 4        146.0
# 5        145.0
#          ...
# 996       41.0
# 997     1271.0
# 998      297.0
# 999      312.0
# 1000     780.0
# Length: 1000, dtype: float64

# %%
df.max(axis=1)
# Out:
# C:\Users\e.kuzmina\AppData\Local\Temp\ipykernel_18408\1471452883.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max(axis=1)
# id
# 1        454.0
# 2        517.0
# 3       1044.0
# 4        146.0
# 5        145.0
#          ...
# 996       41.0
# 997     1271.0
# 998      297.0
# 999      312.0
# 1000     780.0
# Length: 1000, dtype: float64

# %%
df.mean()
# Out:
# C:\Users\e.kuzmina\AppData\Local\Temp\ipykernel_18408\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# age          40.81909
# balance    1334.89400
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\e.kuzmina\AppData\Local\Temp\ipykernel_18408\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# age         39.0
# balance    484.0
# dtype: float64

# %%
df.mode()
# Out:
#     age          job  marital  education  balance housing loan default
# 0  32.0  blue-collar  married  secondary        0     yes   no      no

# %%
df['balance'].values
# Out:
# array([  454,   517,  1044,   146,   145,    11,   298,   905,  -485,
#           10,    78,     0,   223,   387,    96,     0,  -161,  3630,
#          302,  1452,  1651,    84,  2143,   682,   337,  4545,  1698,
#         1367,  3109,   480,  3536,   781,   291,  3145,   -75,  1035,
#          981,   552,   465,   886,  -464,    34,   -74,  1777,  1395,
#         -148,  1843,  1522,   257,  1327,     0,   497,   902,  1311,
#         1596,  2767,     0,   984,    84,   231,  3730,  1139,   388,
#          485,   363,  -313,   278,  -204,  2931,     3,  2244,  5879,
#          871,    35,   757,   115,    51,   580,  4923,  3730,  -605,
#           34,  2237,   285,  -120,  -291, 31472,   529,    35,  1340,
#          149,  5235,  3466,   575,   348,  1096,  1646,     1,    77,
#            0,   676,   556,  3164,   257,     0,     0,  5854,  1168,
#         1029,   685,  2565,  5878,     0,   590,  1538,   260,     0,
# ...

# %%
df['balance'].value_counts()
# Out:
# 0       89
# 71       6
# 4        6
# 618      4
# 366      4
#         ..
# 3387     1
# 3850     1
# 2575     1
# 2442     1
# 780      1
# Name: balance, Length: 765, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'balance', 'housing', 'loan',
#        'default'],
#       dtype='object')

# %%
df[['job', 'marital', 'education','housing', 'loan', 'default']].describe()
# Out:
#                 job  marital  education housing  loan default
# count          1000      897       1000    1000  1000    1000
# unique           12        3          4       2     2       2
# top     blue-collar  married  secondary     yes    no      no
# freq            235      492        515     562   845     915

# %%
df['marital'].nunique()
# Out:
# 3

# %%
df['marital'].unique()
# Out:
# array(['married', 'single', 'divorced', None], dtype=object)

# %%
df['marital'].isna()
# Out:
# id
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 996     False
# 997     False
# 998     False
# 999      True
# 1000    False
# Name: marital, Length: 1000, dtype: bool

# %%
df[df['marital'].isna()]
# Out:
#       age            job marital  education  balance housing loan default
# id
# 14   34.0        student    None   tertiary      387     yes   no      no
# 18   47.0    blue-collar    None  secondary     3630     yes   no      no
# 29   57.0    blue-collar    None    primary     3109      no   no      no
# 37   36.0       services    None  secondary      981      no   no      no
# 42   57.0        retired    None   tertiary       34      no  yes      no
# ..    ...            ...     ...        ...      ...     ...  ...     ...
# 966  45.0    blue-collar    None  secondary      -35     yes  yes      no
# 972   NaN     technician    None  secondary      688      no   no      no
# 983  57.0     management    None   tertiary      334     yes   no      no
# 988  30.0  self-employed    None  secondary      581     yes   no      no
# 999  31.0   entrepreneur    None   tertiary      312      no   no      no
#
# [103 rows x 8 columns]

# %%
df[df['age'].isna()]
# Out:
#      age          job   marital  education  balance housing loan default
# id
# 9    NaN   management   married   tertiary     -485     yes   no     yes
# 19   NaN  blue-collar   married  secondary      302      no  yes      no
# 32   NaN    housemaid    single  secondary      781     yes   no      no
# 43   NaN   technician   married  secondary      -74     yes   no     yes
# 50   NaN      retired  divorced    primary     1327     yes  yes     yes
# ..   ...          ...       ...        ...      ...     ...  ...     ...
# 951  NaN      retired   married  secondary       87      no   no      no
# 959  NaN      retired  divorced  secondary       70     yes   no      no
# 972  NaN   technician      None  secondary      688      no   no      no
# 985  NaN  blue-collar    single  secondary      143     yes   no      no
# 995  NaN   management   married  secondary      106      no   no      no
#
# [99 rows x 8 columns]

# %%
df[(df['age'].isna()) & (df['marital'].isna())]
# Out:
#      age          job marital  education  balance housing loan default
# id
# 101  NaN  blue-collar    None    primary      676     yes   no      no
# 320  NaN   management    None   tertiary       15      no   no      no
# 500  NaN   technician    None   tertiary      192     yes   no      no
# 532  NaN  blue-collar    None  secondary     2160      no   no      no
# 748  NaN   technician    None  secondary     1353      no   no      no
# 885  NaN     services    None  secondary     1286     yes  yes      no
# 972  NaN   technician    None  secondary      688      no   no      no

# %%
df[ ((df['housing'] == 'yes') | (df['loan'] == 'yes')) & (df['age'] <= 23)]
# Out:
#        age          job marital  education  balance housing loan default
# id
# 102   23.0      student  single  secondary      556     yes   no      no
# 353   22.0     services  single  secondary      236     yes   no      no
# 437   23.0  blue-collar  single  secondary      214     yes   no      no
# 682   21.0       admin.  single  secondary       66     yes   no      no
# 1000  23.0  blue-collar  single  secondary      780     yes   no      no
